# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from functools import partial
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (2, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 2 and skip_window = 2:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of']
#     labels: ['originated', 'a', 'as', 'originated', 'as', 'a', 'abuse', 'a']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.176452
# Nearest to most: toxins, undesired, toy, irreversible, canonically, parque, insubordination, kashmir,
# Nearest to have: coloureds, oceans, what, enactments, hmmwv, portsmouth, bootlegged, scholars,
# Nearest to he: suspected, clara, alam, burned, azerbaijan, affiliation, sanitation, reactivity,
# Nearest to seven: rds, abhidhamma, anand, othniel, unable, bbn, panhandle, worcestershire,
# Nearest to see: even, gambeson, guernsey, overwhelmed, professor, sufficed, chernobyl, gracefully,
# Nearest to war: navigable, phenomenological, vip, furlongs, fission, hern, monument, earner,
# Nearest to only: jai, cuts, haploid, nyquist, functionals, newsreel, methodists, reproductive,
# Nearest to two: palm, irate, devolved, insurrection, expound, ecowas, mosfet, objective,
# Nearest to th: applause, founders, carolingian, jervis, postgresql, burglar, sonar, melon,
# Nearest to or: mining, mirabeau, excellency, jure, yy, sunnah, possibility, seeming,
# Nearest to may: tetris, eighteen, seagram, ishiro, icelanders, homegrown, longbow, expend,
# Nearest to after: keel, daly, matres, strand, trainer, shrublands, collett, gradualism,
# Nearest to be: resurface, sustained, arousing, greet, valet, autobahn, allowance, photographers,
# Nearest to their: walid, aix, constitutionally, mt, fisherman, scope, out, curling,
# Nearest to five: adoption, strasberg, gcl, dillon, borrowed, gmt, hindemith, parole,
# Nearest to had: leicester, completed, namco, snorri, weightings, evenly, laurel, descriptors,
# Average loss at step 2000: 4.363921
# Average loss at step 4000: 3.865755
# Average loss at step 6000: 3.787532
# Average loss at step 8000: 3.688783
# Average loss at step 10000: 3.616144
# Nearest to most: immigrants, toxins, scarlatti, approaches, hildegard, cubs, bullpen, walker,
# Nearest to have: be, had, has, are, were, drake, confrontation, humorously,
# Nearest to he: it, she, they, who, there, peroxide, imap, stereotyped,
# Nearest to seven: six, eight, nine, four, three, five, zero, two,
# Nearest to see: even, inbound, professor, managers, contractors, cyborg, ystok, automata,
# Nearest to war: brisance, easy, lima, vip, locale, wine, ligny, annexation,
# Nearest to only: jai, vessels, irrational, purposely, respected, auctioned, cob, haploid,
# Nearest to two: three, five, four, six, seven, eight, zero, nine,
# Nearest to th: applause, postgresql, jervis, ridge, rfc, zhukov, est, listing,
# Nearest to or: and, bandwidth, than, housing, condemning, emulates, expenditures, inasmuch,
# Nearest to may: would, must, leasing, will, misunderstanding, seagram, seen, ridicule,
# Nearest to after: before, hillary, baudot, meades, lawful, days, attacking, chandler,
# Nearest to be: have, is, by, was, are, friar, refer, been,
# Nearest to their: his, its, out, aliyah, mt, konerko, the, nada,
# Nearest to five: six, eight, four, seven, nine, three, two, zero,
# Nearest to had: has, was, have, completed, were, achille, marching, funding,
# Average loss at step 12000: 3.607678
# Average loss at step 14000: 3.569725
# Average loss at step 16000: 3.409809
# Average loss at step 18000: 3.458709
# Average loss at step 20000: 3.544378
# Nearest to most: more, many, walker, hildegard, bullpen, scarlatti, approaches, toxins,
# Nearest to have: had, were, be, has, are, drake, selamat, humorously,
# Nearest to he: it, she, they, there, who, khalid, never, ciphertext,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to see: cyborg, inbound, obstacle, barak, cp, sess, even, suffixed,
# Nearest to war: brisance, lima, easy, locale, theodosius, wine, hava, rashi,
# Nearest to only: jai, vessels, firebird, not, purposely, need, tucker, intelsat,
# Nearest to two: three, four, five, six, eight, one, seven, zero,
# Nearest to th: ridge, listing, postgresql, jervis, zhukov, nd, applause, bc,
# Nearest to or: and, than, terrell, expenditures, housing, with, sram, pronouncing,
# Nearest to may: would, can, must, will, should, could, leasing, might,
# Nearest to after: before, from, hillary, by, baudot, frivolous, next, jester,
# Nearest to be: have, was, been, by, is, were, refer, exacerbating,
# Nearest to their: its, his, the, her, some, konerko, our, nada,
# Nearest to five: three, seven, six, eight, four, zero, two, nine,
# Nearest to had: have, has, were, was, marching, achille, kronstadt, since,
# Average loss at step 22000: 3.507880
# Average loss at step 24000: 3.485624
# Average loss at step 26000: 3.480242
# Average loss at step 28000: 3.484695
# Average loss at step 30000: 3.504025
# Nearest to most: more, many, some, walker, scarlatti, romana, resumes, theocratic,
# Nearest to have: had, has, were, are, be, drake, having, surreptitiously,
# Nearest to he: she, it, they, who, there, neorealism, never, ciphertext,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to see: biotechnology, inbound, barak, obstacle, cyborg, sliding, larry, elegies,
# Nearest to war: brisance, theodosius, lima, easy, locale, rashi, icelandic, cultured,
# Nearest to only: firebird, not, indicates, sloti, geared, compensating, need, but,
# Nearest to two: four, three, one, five, six, seven, eight, zero,
# Nearest to th: nd, bc, listing, six, sulaiman, ridge, seven, eight,
# Nearest to or: and, housing, but, than, conscientious, martian, jam, wilmut,
# Nearest to may: can, would, must, should, will, could, might, leasing,
# Nearest to after: before, during, since, when, hillary, from, frivolous, on,
# Nearest to be: have, been, refer, is, are, were, exacerbating, was,
# Nearest to their: its, his, the, her, our, some, these, informative,
# Nearest to five: four, six, eight, three, seven, nine, zero, two,
# Nearest to had: have, has, was, were, since, achille, having, is,
# Average loss at step 32000: 3.500734
# Average loss at step 34000: 3.497431
# Average loss at step 36000: 3.460301
# Average loss at step 38000: 3.299805
# Average loss at step 40000: 3.427715
# Nearest to most: more, many, walker, fullness, deem, tailor, hildegard, romana,
# Nearest to have: had, has, were, be, are, receive, drake, having,
# Nearest to he: she, it, they, who, there, ciphertext, i, biafra,
# Nearest to seven: five, nine, six, eight, four, three, zero, two,
# Nearest to see: larry, biotechnology, obstacle, undetected, inbound, kampaku, pancras, unrounded,
# Nearest to war: lima, brisance, theodosius, icelandic, feng, cultured, session, hu,
# Nearest to only: firebird, arching, not, it, geared, pints, compensating, sosa,
# Nearest to two: three, four, five, six, seven, one, eight, nine,
# Nearest to th: nd, bc, ad, chungcheong, ridge, postgresql, heller, ell,
# Nearest to or: and, than, enol, a, conscientious, guru, henning, celery,
# Nearest to may: can, would, must, will, could, should, might, cannot,
# Nearest to after: before, during, frivolous, chandler, since, from, when, egoist,
# Nearest to be: been, have, refer, are, was, become, were, is,
# Nearest to their: its, his, her, our, the, informative, these, konerko,
# Nearest to five: seven, six, four, three, eight, nine, two, zero,
# Nearest to had: has, have, was, were, novum, mapquest, having, been,
# Average loss at step 42000: 3.432732
# Average loss at step 44000: 3.457170
# Average loss at step 46000: 3.448588
# Average loss at step 48000: 3.354535
# Average loss at step 50000: 3.390101
# Nearest to most: more, many, walker, theocratic, less, unionist, innovated, scarlatti,
# Nearest to have: had, has, be, were, are, having, receive, include,
# Nearest to he: she, it, they, who, there, never, stereotyped, soon,
# Nearest to seven: six, eight, nine, four, three, five, zero, two,
# Nearest to see: includes, biotechnology, include, poetry, sliding, external, spurs, show,
# Nearest to war: theodosius, brisance, icelandic, lima, feng, hu, cultured, hava,
# Nearest to only: firebird, arching, until, compensating, normally, uneventful, sloti, facts,
# Nearest to two: three, four, six, five, seven, one, eight, nine,
# Nearest to th: nd, ad, bc, one, bce, chungcheong, heller, st,
# Nearest to or: and, than, sram, imperceptible, photonic, wig, terrell, jam,
# Nearest to may: can, would, must, will, should, might, could, cannot,
# Nearest to after: before, during, when, from, since, into, frivolous, while,
# Nearest to be: have, been, was, refer, were, being, are, become,
# Nearest to their: its, his, her, our, the, both, informative, these,
# Nearest to five: four, six, three, seven, eight, two, nine, zero,
# Nearest to had: has, have, was, having, were, novum, been, phane,
# Average loss at step 52000: 3.432068
# Average loss at step 54000: 3.427321
# Average loss at step 56000: 3.438934
# Average loss at step 58000: 3.395474
# Average loss at step 60000: 3.394346
# Nearest to most: more, some, many, use, walker, theocratic, deem, innovated,
# Nearest to have: had, has, are, were, receive, be, include, require,
# Nearest to he: she, it, they, there, who, never, leptons, smoot,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to see: include, but, biotechnology, external, mythological, includes, sliding, including,
# Nearest to war: theodosius, icelandic, feng, lima, hu, cultured, brisance, annexation,
# Nearest to only: until, to, already, firebird, not, but, dns, first,
# Nearest to two: four, three, five, six, one, seven, eight, zero,
# Nearest to th: nd, bce, eight, ad, chungcheong, bc, rd, one,
# Nearest to or: and, than, jam, guru, sram, photonic, terrell, like,
# Nearest to may: can, would, will, must, might, could, should, cannot,
# Nearest to after: before, during, when, despite, hillary, since, pesky, following,
# Nearest to be: been, have, is, refer, become, are, was, produce,
# Nearest to their: its, his, her, the, our, these, informative, them,
# Nearest to five: six, four, eight, three, seven, nine, zero, two,
# Nearest to had: has, have, was, having, were, been, mexicans, mapquest,
# Average loss at step 62000: 3.245377
# Average loss at step 64000: 3.259109
# Average loss at step 66000: 3.405500
# Average loss at step 68000: 3.394832
# Average loss at step 70000: 3.355180
# Nearest to most: more, many, less, use, theocratic, some, walker, especially,
# Nearest to have: had, has, were, are, be, include, receive, require,
# Nearest to he: she, it, they, there, who, smoot, we, never,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to see: include, external, list, mythological, references, includes, but, sliding,
# Nearest to war: theodosius, feng, icelandic, lima, disulfide, cultured, annexation, hu,
# Nearest to only: dns, already, steinberg, move, normally, stadia, always, need,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to th: ad, nd, bc, bce, fifth, third, st, rd,
# Nearest to or: and, than, like, but, katanga, dunes, pronouncing, terrell,
# Nearest to may: can, will, would, must, might, should, could, cannot,
# Nearest to after: before, during, when, despite, until, pesky, while, hillary,
# Nearest to be: been, is, have, become, being, were, are, autoimmune,
# Nearest to their: its, his, her, the, our, these, your, some,
# Nearest to five: four, six, eight, three, seven, nine, zero, two,
# Nearest to had: has, have, was, were, having, mexicans, been, never,
# Average loss at step 72000: 3.376871
# Average loss at step 74000: 3.351918
# Average loss at step 76000: 3.313966
# Average loss at step 78000: 3.357902
# Average loss at step 80000: 3.378924
# Nearest to most: many, more, some, especially, less, particularly, theocratic, among,
# Nearest to have: had, has, are, were, having, be, include, require,
# Nearest to he: she, it, they, there, who, soon, we, never,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to see: include, mythological, includes, but, deo, sliding, lillehammer, external,
# Nearest to war: theodosius, feng, hu, icelandic, annexation, lima, recognizably, reassembled,
# Nearest to only: always, best, transfusion, dns, normally, until, lasso, stadia,
# Nearest to two: three, four, six, five, seven, eight, one, zero,
# Nearest to th: bc, bce, nd, ad, fifth, rd, chungcheong, third,
# Nearest to or: and, than, but, while, katanga, terrell, hellbender, jam,
# Nearest to may: can, would, must, could, might, will, should, cannot,
# Nearest to after: before, during, when, despite, while, following, until, pesky,
# Nearest to be: been, become, have, being, were, prove, was, refer,
# Nearest to their: its, his, her, our, your, my, informative, the,
# Nearest to five: four, six, eight, seven, nine, three, zero, two,
# Nearest to had: have, has, were, having, was, been, began, never,
# Average loss at step 82000: 3.408507
# Average loss at step 84000: 3.407093
# Average loss at step 86000: 3.386148
# Average loss at step 88000: 3.352467
# Average loss at step 90000: 3.368301
# Nearest to most: many, some, more, less, among, use, especially, phases,
# Nearest to have: had, has, were, are, require, be, receive, include,
# Nearest to he: she, they, it, there, who, but, stereotyped, probably,
# Nearest to seven: eight, six, five, four, nine, three, one, zero,
# Nearest to see: external, includes, links, sliding, include, references, deo, but,
# Nearest to war: theodosius, feng, reassembled, fund, peasant, icelandic, recognizably, annexation,
# Nearest to only: even, pathological, another, normally, always, dns, transfusion, geared,
# Nearest to two: three, four, five, six, eight, seven, one, zero,
# Nearest to th: bc, fifth, bce, ad, rd, nd, chungcheong, fourth,
# Nearest to or: and, wig, paracelsus, jam, than, terrell, but, org,
# Nearest to may: can, could, must, would, might, will, should, cannot,
# Nearest to after: before, during, when, despite, without, while, until, following,
# Nearest to be: been, become, being, have, was, is, prove, are,
# Nearest to their: its, his, her, our, your, informative, my, these,
# Nearest to five: four, eight, seven, three, six, nine, two, zero,
# Nearest to had: has, have, was, were, having, since, never, began,
# Average loss at step 92000: 3.399376
# Average loss at step 94000: 3.256870
# Average loss at step 96000: 3.357350
# Average loss at step 98000: 3.240785
# Average loss at step 100000: 3.357205
# Nearest to most: more, less, especially, many, particularly, some, walker, phases,
# Nearest to have: had, has, be, require, are, were, contain, seem,
# Nearest to he: she, it, they, there, who, never, we, smoot,
# Nearest to seven: four, eight, nine, five, six, three, zero, two,
# Nearest to see: includes, external, references, links, sliding, refer, include, refers,
# Nearest to war: theodosius, feng, recognizably, noticed, annexation, reassembled, icelandic, individualized,
# Nearest to only: still, best, approximately, adrift, always, no, not, pathological,
# Nearest to two: four, three, five, six, seven, eight, one, zero,
# Nearest to th: bc, fifth, rd, nd, chungcheong, bce, ad, fourth,
# Nearest to or: and, than, guru, wig, but, jam, tiles, thermopylae,
# Nearest to may: can, could, should, must, would, might, will, cannot,
# Nearest to after: before, during, when, despite, without, while, following, until,
# Nearest to be: been, have, being, is, become, refer, prove, are,
# Nearest to their: its, his, her, our, your, the, informative, these,
# Nearest to five: seven, four, eight, six, zero, three, nine, two,
# Nearest to had: has, have, was, were, having, since, mexicans, mapquest,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# Refactor word2wec implementation
# So it can be resued with CBOW model
def create_word2vec_graph(
        batch_size,
        vocabulary_size,
        embedding_size,
        num_neg_softmax_examples_sampled,

        valid_examples,
    ):
    """
    Create tf graph representation for word2vec model
    """
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal(
            [vocabulary_size, embedding_size],
            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(
            weights=softmax_weights, biases=softmax_biases, 
            inputs=embed, labels=train_labels, 
            num_sampled=num_neg_softmax_examples_sampled, num_classes=vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
       normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))  
    return (
        similarity,
        normalized_embeddings,
        
        train_dataset,
        train_labels,
        
        optimizer,
        loss
    )
    

def run_word2vec_session(
        session,
    
        num_steps,
        batch_size,
        random_valid_eval_size,
    
        reverse_dictionary,
    
        train_dataset,
        train_labels,
        valid_examples,
    
        optimizer,
        loss,
    
        similarity,
        normalized_embeddings,
        
        data,
        generate_batch,
    ):
    """
    Run session for word2vec model
    """
    def _print_validation_similarity():
        sim = similarity.eval()
        for i in range(random_valid_eval_size):
            valid_word = reverse_dictionary[valid_examples[i]]
            top_k = 8 # number of nearest neighbors
            nearest = (-sim[i, :]).argsort()[1:top_k+1]
            log = 'Nearest to %s:' % valid_word
            for k in range(top_k):
                close_word = reverse_dictionary[nearest[k]]
                log = '%s %s,' % (log, close_word)
            print(log)  
            
    def _run_step(step, generator):
        batch_data, batch_labels = next(generator)
        feed_dict = {
            train_dataset : batch_data, 
            train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)

        if step % 10000 == 0:
            _print_validation_similarity()
        return l
    
    tf.global_variables_initializer().run()
    average_loss = 0
    data_batches_generator = generate_batch(data, batch_size)
    for step in range(num_steps):
        l = _run_step(step, data_batches_generator)
        average_loss += l
        if step % 2000 == 0 and step != 0:
            average_loss = average_loss / 2000
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
    
    final_embeddings = normalized_embeddings.eval()
    return final_embeddings

def plot_word2vec_2d(
        final_embeddings,
    
        num_points_to_show,
        reverse_dictionary,
    ):
    """
    Plot cloud of words using TSNE
    """
    def _plot(embeddings, labels):
        assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
        pylab.figure(figsize=(15,15))  # in inches
        for i, label in enumerate(labels):
            x, y = embeddings[i,:]
            pylab.scatter(x, y)
            pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
        pylab.show()

    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
    two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points_to_show+1, :])
    words = [reverse_dictionary[i] for i in range(1, num_points_to_show+1)]
    _plot(two_d_embeddings, words)
    
def run_word2vec_model(
        batch_size,
        vocabulary_size,
        embedding_size,
        num_neg_softmax_examples_sampled,
        num_steps,
        num_points_to_show,

        valid_size,
        valid_window,
        reverse_dictionary,
    
        data,
        generate_batch_func,
    ):

    valid_examples = np.array(random.sample(range(valid_window), valid_size))

    tf.reset_default_graph()
    graph = tf.Graph()
    with graph.as_default(), tf.device('/cpu:0'):
        (
            similarity,
            normalized_embeddings,
        
            train_dataset,
            train_labels,
        
            optimizer,
            loss
        ) = create_word2vec_graph(
            batch_size,
            vocabulary_size,
            embedding_size,
            num_neg_softmax_examples_sampled,
            valid_examples,)
    
    with tf.Session(graph=graph) as session:
        final_embeddings = run_word2vec_session(
            session,
    
            num_steps,
            batch_size,
            valid_size,
    
            reverse_dictionary,
    
            train_dataset,
            train_labels,
            valid_examples,
    
            optimizer,
            loss,
    
           similarity,
           normalized_embeddings,
       
            data,
            generate_batch_func,)
    plot_word2vec_2d(
        final_embeddings,
    
        num_points_to_show,
        reverse_dictionary)

# %%
def generate_skip_gram_batch(
        data, batch_size, num_skips, skip_window):
    data_index = 0
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    while(True):
        batch = np.ndarray(shape=(batch_size), dtype=np.int32)
        labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
        span = 2 * skip_window + 1 # [ skip_window target skip_window ]
        buffer = collections.deque(maxlen=span)
        for _ in range(span):
            buffer.append(data[data_index])
            data_index = (data_index + 1) % len(data)
        for i in range(batch_size // num_skips):
            target = skip_window  # target label at the center of the buffer
            targets_to_avoid = [ skip_window ]
            for j in range(num_skips):
                while target in targets_to_avoid:
                    target = random.randint(0, span - 1)
                targets_to_avoid.append(target)
                batch[i * num_skips + j] = buffer[skip_window]
                labels[i * num_skips + j, 0] = buffer[target]
            buffer.append(data[data_index])
            data_index = (data_index + 1) % len(data)
        yield batch, labels
    

NUM_SKIPS = 2
SKIP_WINDOW = 1

BATCH_SIZE = 128
VOCABULARY_SIZE = 50000
EMBEDDING_SIZE = 28 # Dimension of the embedding vector.
NUM_NEG_SOFTMAX_EXAMPLES_SAMPLED = 64
NUM_STEPS = 100001
NUM_POINTS_TO_SHOW = 400

VALID_SIZE = 16
VALID_WINDOW = 100

run_word2vec_model(
    BATCH_SIZE,
    VOCABULARY_SIZE,
    EMBEDDING_SIZE,
    NUM_NEG_SOFTMAX_EXAMPLES_SAMPLED,
    NUM_STEPS,
    NUM_POINTS_TO_SHOW,

    VALID_SIZE,
    VALID_WINDOW,
    reverse_dictionary,
    
    data,
    partial(
        generate_skip_gram_batch,
        num_skips=NUM_SKIPS, 
        skip_window=SKIP_WINDOW)
)
# Out:
# Nearest to however: outnumber, practitioner, unwillingly, rowdy, got, gymnasts, bogies, oskar,
# Nearest to people: ocp, krajina, cinnamon, cornelia, lymphoma, staunchly, trisha, pio,
# Nearest to world: viper, hyperinsulinism, noa, droit, cures, flanagan, carey, frivolous,
# Nearest to to: omnia, hathor, formerly, secant, extinctions, supposes, questionnaire, volap,
# Nearest to when: fortunately, andechs, midwife, vinci, tour, articulations, eurovision, playable,
# Nearest to may: tradeoff, iadb, arrears, amway, volunteered, voltaic, stwa, aquarists,
# Nearest to is: achieves, antonin, timothy, shoulder, abolished, athlon, avoidance, recast,
# Nearest to see: rowdy, wilcox, peculiarities, horticultural, suv, epilepsy, bending, bradycardia,
# Nearest to during: qur, stuck, hamel, yom, sza, maintains, rom, exhorts,
# Nearest to two: henry, arrayed, tainted, ericales, frites, afflicted, assemble, kushans,
# Nearest to as: sarcophagus, intercept, angli, tithes, handguns, composting, maximin, mayotte,
# Nearest to it: pharsalus, curtailed, bicoid, asser, ampersand, shahada, hj, fixtures,
# Nearest to most: weblogs, moseley, huey, bsi, trinomial, nerve, benevento, macrae,
# Nearest to six: deficient, steals, burgesses, crusoe, radicalism, zeeland, rightly, acharya,
# Nearest to seven: bettors, gnomes, friedman, confidence, disallowed, lamiaceae, discus, selig,
# Nearest to or: odds, pyramids, prick, robert, produce, ua, corporal, ramone,
# Average loss at step 2000: 4.445759
# Average loss at step 4000: 3.913750
# Average loss at step 6000: 3.838622
# Average loss at step 8000: 3.736881
# Nearest to however: although, when, while, though, but, incapacitation, without, exaggerated,
# Nearest to people: singles, vols, lined, coloureds, your, koyaanisqatsi, cinnamon, yod,
# Nearest to world: tsunami, birthplace, government, whereupon, modest, explainable, affiliates, dryden,
# Nearest to to: visited, formerly, amphisbaena, decisive, villiers, userbase, albert, robe,
# Nearest to when: childs, however, although, though, where, while, if, since,
# Nearest to may: will, would, can, should, gory, could, broadened, sublime,
# Nearest to is: was, has, are, constructivism, revealed, alg, while, vats,
# Nearest to see: prints, davenport, politico, donkeys, excludes, excommunication, amounting, noble,
# Nearest to during: within, inventors, giacomo, while, neck, under, after, in,
# Nearest to two: four, three, five, six, voluntarily, seven, isbn, eight,
# Nearest to as: absorption, arboretum, mithraeum, mes, became, cripps, plc, walruses,
# Nearest to it: which, there, she, he, they, this, no, often,
# Nearest to most: olympics, ziibi, sleeping, actual, modulation, irv, throttled, broadcasting,
# Nearest to six: seven, eight, four, five, three, nine, two, zero,
# Nearest to seven: six, eight, four, five, three, nine, zero, two,
# Nearest to or: and, narrowest, seer, appreciation, expectancy, alabama, southerner, lucie,
# Average loss at step 10000: 3.660705
# Average loss at step 12000: 3.656873
# Average loss at step 14000: 3.618690
# Average loss at step 16000: 3.451280
# Average loss at step 18000: 3.503383
# Nearest to however: but, though, when, without, heron, although, since, before,
# Nearest to people: men, singles, koyaanisqatsi, darkly, instructing, ic, years, disseminated,
# Nearest to world: whereupon, tsunami, generated, belief, government, explainable, blot, sie,
# Nearest to to: userbase, visited, villiers, decisive, formerly, beyond, amphisbaena, tabulating,
# Nearest to when: although, while, if, since, where, before, however, though,
# Nearest to may: would, will, can, could, should, must, gory, broadened,
# Nearest to is: was, has, became, becomes, does, irvine, monumental, gives,
# Nearest to see: affair, kern, xii, amounting, ctrl, donkeys, prints, bearded,
# Nearest to during: within, under, upon, in, ozzie, through, while, until,
# Nearest to two: three, five, four, six, seven, one, isbn, eight,
# Nearest to as: mes, surfer, mithraeum, arboretum, hamsters, walruses, adnan, vasari,
# Nearest to it: he, she, there, watering, ais, intends, lagrange, lieder,
# Nearest to most: sleeping, olympics, throttled, lyc, ziibi, actual, autistic, mayan,
# Nearest to six: seven, four, three, five, eight, nine, two, zero,
# Nearest to seven: eight, six, four, three, five, nine, two, pp,
# Nearest to or: and, like, coward, holman, seer, aa, necessitates, than,
# Average loss at step 20000: 3.585914
# Average loss at step 22000: 3.550360
# Average loss at step 24000: 3.540391
# Average loss at step 26000: 3.533319
# Average loss at step 28000: 3.519684
# Nearest to however: but, although, though, while, when, before, makes, meant,
# Nearest to people: men, koyaanisqatsi, darkly, singles, women, thuringia, picirilli, reasons,
# Nearest to world: whereupon, tsunami, sie, belief, explainable, affiliates, trisomy, generated,
# Nearest to to: visited, formerly, userbase, boutique, villiers, will, armand, amphisbaena,
# Nearest to when: while, if, before, although, though, where, until, under,
# Nearest to may: would, could, will, should, can, must, might, gory,
# Nearest to is: was, becomes, became, does, haldeman, irvine, while, monumental,
# Nearest to see: bearded, ravine, xii, kern, affair, overseer, ctrl, riggs,
# Nearest to during: until, within, under, after, before, through, in, since,
# Nearest to two: three, four, five, seven, one, six, meters, voluntarily,
# Nearest to as: fascist, mithraeum, mes, vasari, surfer, walruses, lokasenna, christchurch,
# Nearest to it: she, he, there, noisy, lieder, filtration, lagrange, now,
# Nearest to most: mayan, ziibi, lyc, maeshowe, autocode, sleeping, protest, thumb,
# Nearest to six: seven, eight, four, five, nine, three, pp, two,
# Nearest to seven: six, eight, four, five, nine, three, two, one,
# Nearest to or: and, southerner, pancake, holman, lucie, appreciation, denominated, like,
# Average loss at step 30000: 3.556192
# Average loss at step 32000: 3.553143
# Average loss at step 34000: 3.543366
# Average loss at step 36000: 3.512190
# Average loss at step 38000: 3.379903
# Nearest to however: but, though, holding, that, while, before, meant, invest,
# Nearest to people: men, muslims, thuringia, others, women, darkly, guardian, cottages,
# Nearest to world: tsunami, affiliates, despise, tat, whereupon, explainable, generated, poetical,
# Nearest to to: villiers, userbase, explode, visited, papier, mvp, bondi, boutique,
# Nearest to when: while, before, until, after, lawson, microstates, if, although,
# Nearest to may: can, should, could, will, must, might, would, cannot,
# Nearest to is: becomes, was, hosted, monumental, rowboat, rub, midshipman, bbb,
# Nearest to see: wattle, xii, include, riggs, recognize, bearded, freiherr, infanta,
# Nearest to during: within, until, since, against, before, under, through, towards,
# Nearest to two: three, four, five, six, seven, hyksos, meters, eight,
# Nearest to as: walruses, mes, mithraeum, bisected, hamsters, unneeded, sneak, adom,
# Nearest to it: he, she, which, there, peebles, now, actually, lagrange,
# Nearest to most: ziibi, mayan, platforms, maeshowe, lyc, lists, universal, randall,
# Nearest to six: seven, four, five, eight, three, nine, two, pages,
# Nearest to seven: six, five, eight, four, nine, three, zero, two,
# Nearest to or: and, dilmun, madeleine, coward, sabres, gamal, pixel, profile,
# Average loss at step 40000: 3.482652
# Average loss at step 42000: 3.483846
# Average loss at step 44000: 3.502448
# Average loss at step 46000: 3.498316
# Average loss at step 48000: 3.407102
# Nearest to however: but, though, although, where, while, since, invest, heron,
# Nearest to people: men, generals, others, lepton, cases, players, thuringia, women,
# Nearest to world: tsunami, tat, despise, bibliotheca, trisomy, hitting, affiliates, whereupon,
# Nearest to to: userbase, atheromatous, papier, explode, bondi, visited, spiritualist, armand,
# Nearest to when: while, before, after, although, until, though, but, where,
# Nearest to may: should, must, can, might, will, could, would, cannot,
# Nearest to is: was, becomes, contains, haldeman, gives, rowboat, includes, courtney,
# Nearest to see: wattle, include, recognize, xii, compulsion, baumgarten, wikiproject, riggs,
# Nearest to during: within, under, until, in, since, against, at, after,
# Nearest to two: three, four, one, five, six, seven, hyksos, eight,
# Nearest to as: walruses, leste, fascist, adom, matrix, cookie, mes, warwickshire,
# Nearest to it: he, she, there, lieder, this, now, peebles, ais,
# Nearest to most: ziibi, mayan, neuropsychological, universal, hindustani, autocode, assassination, maeshowe,
# Nearest to six: eight, seven, four, three, five, nine, two, kg,
# Nearest to seven: six, eight, four, three, nine, five, two, zero,
# Nearest to or: pancake, and, nabokov, gravis, bennington, laugh, adriaan, gamal,
# Average loss at step 50000: 3.442201
# Average loss at step 52000: 3.492437
# Average loss at step 54000: 3.482044
# Average loss at step 56000: 3.488399
# Average loss at step 58000: 3.456156
# Nearest to however: but, since, though, that, although, dannebrog, heron, meant,
# Nearest to people: men, women, others, muslims, vieux, players, christians, generals,
# Nearest to world: trisomy, bibliotheca, sie, pusan, affiliates, tsunami, notion, algebraically,
# Nearest to to: userbase, tabulating, villiers, papier, amphisbaena, bondi, explode, armand,
# Nearest to when: while, although, before, until, if, lawson, after, where,
# Nearest to may: should, might, can, must, could, will, would, cannot,
# Nearest to is: becomes, remains, was, glittering, contains, hosted, haldeman, rowboat,
# Nearest to see: wattle, include, compulsion, recognize, xii, mired, riggs, ravine,
# Nearest to during: after, within, despite, following, since, until, before, montrose,
# Nearest to two: three, four, five, seconds, feet, six, meters, one,
# Nearest to as: harbor, mithraeum, mears, walruses, adom, teller, mes, surfer,
# Nearest to it: she, he, this, there, ais, lieder, lagrange, watering,
# Nearest to most: especially, mayan, neuropsychological, ziibi, hindustani, orchestral, camped, ethertype,
# Nearest to six: eight, four, five, seven, three, nine, ghz, metres,
# Nearest to seven: eight, six, four, five, nine, three, iso, one,
# Nearest to or: and, pancake, heavy, nabokov, immunoglobulins, embark, gnomes, pneumatic,
# Average loss at step 60000: 3.449761
# Average loss at step 62000: 3.328503
# Average loss at step 64000: 3.332607
# Average loss at step 66000: 3.462755
# Average loss at step 68000: 3.454451
# Nearest to however: but, although, though, where, that, allows, since, while,
# Nearest to people: women, men, others, muslims, players, things, countries, speer,
# Nearest to world: trisomy, tsunami, bibliotheca, sie, affiliates, algebraically, departed, infectious,
# Nearest to to: userbase, mitochondrial, bondi, rewritable, spiritualist, explode, papier, villiers,
# Nearest to when: while, if, before, unless, where, enjoys, although, lawson,
# Nearest to may: can, might, should, could, must, would, will, cannot,
# Nearest to is: was, becomes, contains, remains, haldeman, requires, rowboat, glittering,
# Nearest to see: include, mired, wattle, compulsion, riggs, ravine, cherokees, integral,
# Nearest to during: despite, after, until, under, shevat, since, before, within,
# Nearest to two: three, four, meters, five, six, seconds, seven, one,
# Nearest to as: proclamation, adom, matrix, walruses, warwickshire, rub, bisected, mears,
# Nearest to it: she, he, there, lieder, vigilante, this, still, lagrange,
# Nearest to most: neuropsychological, ziibi, mayan, hindustani, transparent, ethertype, stipulated, basingstoke,
# Nearest to six: seven, four, eight, five, three, nine, metres, two,
# Nearest to seven: six, four, eight, five, three, nine, two, deaths,
# Nearest to or: and, pancake, chroma, immunoglobulins, algeciras, heavy, disappearances, alexey,
# Average loss at step 70000: 3.425985
# Average loss at step 72000: 3.429303
# Average loss at step 74000: 3.413676
# Average loss at step 76000: 3.376717
# Average loss at step 78000: 3.408104
# Nearest to however: but, although, thus, that, though, while, despite, where,
# Nearest to people: men, women, children, electrolytes, speer, others, countries, generals,
# Nearest to world: trisomy, tsunami, treasurer, bibliotheca, sie, chaplin, henriette, stadium,
# Nearest to to: userbase, papier, atheromatous, bondi, bonham, villiers, spiritualist, feather,
# Nearest to when: before, while, after, until, enjoys, despite, unless, lawson,
# Nearest to may: might, should, must, could, would, can, will, cannot,
# Nearest to is: was, becomes, remains, haldeman, requires, emigrants, glittering, rowboat,
# Nearest to see: include, strat, beowulf, nouveaux, desktop, emulating, wattle, deluded,
# Nearest to during: despite, after, shevat, until, throughout, before, in, within,
# Nearest to two: three, six, four, five, one, seven, hyksos, fm,
# Nearest to as: adom, walruses, harbor, cookie, matrix, noun, mears, troyes,
# Nearest to it: she, he, itself, there, lieder, sewers, neither, guangzhou,
# Nearest to most: mayan, neuropsychological, especially, ziibi, hindustani, ethertype, transparent, facets,
# Nearest to six: four, seven, five, eight, three, nine, two, metres,
# Nearest to seven: six, five, eight, four, three, nine, cet, zero,
# Nearest to or: and, immunoglobulins, pancake, gravis, nabokov, laugh, regio, chroma,
# Average loss at step 80000: 3.437727
# Average loss at step 82000: 3.462553
# Average loss at step 84000: 3.465369
# Average loss at step 86000: 3.442094
# Average loss at step 88000: 3.405703
# Nearest to however: but, although, since, that, nevertheless, indeed, though, basilisk,
# Nearest to people: women, troubadour, speer, timberlake, persons, men, children, christians,
# Nearest to world: trisomy, sie, sahel, departed, bibliotheca, tsunami, vida, henriette,
# Nearest to to: userbase, papier, bondi, bonham, villiers, towards, atheromatous, robe,
# Nearest to when: while, before, until, novice, since, although, enjoys, if,
# Nearest to may: might, could, can, must, should, will, would, cannot,
# Nearest to is: was, requires, becomes, haldeman, contains, remains, rowboat, glittering,
# Nearest to see: include, beowulf, xii, nouveaux, includes, deluded, wattle, cherokees,
# Nearest to during: despite, until, within, through, shevat, under, while, throughout,
# Nearest to two: three, four, fm, five, one, seven, six, bitrate,
# Nearest to as: adom, cookie, walruses, mears, acoustical, noun, gettier, harbor,
# Nearest to it: he, she, itself, there, lieder, watering, stricken, ornithologists,
# Nearest to most: neuropsychological, especially, particularly, mayan, gripping, transparent, hindustani, ziibi,
# Nearest to six: seven, eight, four, five, three, nine, pp, cet,
# Nearest to seven: eight, six, four, five, three, nine, cet, one,
# Nearest to or: and, pancake, immunoglobulins, piecemeal, chroma, impediments, contractor, stellar,
# Average loss at step 90000: 3.423926
# Average loss at step 92000: 3.452762
# Average loss at step 94000: 3.328043
# Average loss at step 96000: 3.410918
# Average loss at step 98000: 3.302598
# Nearest to however: but, although, indeed, that, though, since, webpages, where,
# Nearest to people: women, children, men, troubadour, persons, fans, citizens, players,
# Nearest to world: trisomy, treasurer, foundation, stadium, departed, halls, sie, vida,
# Nearest to to: userbase, papier, bondi, atheromatous, villiers, towards, boutique, explode,
# Nearest to when: while, although, before, until, unless, if, enjoys, where,
# Nearest to may: could, can, must, might, should, will, would, cannot,
# Nearest to is: was, becomes, haldeman, became, produces, shiraz, akayev, requires,
# Nearest to see: xii, compulsion, cherokees, beowulf, mired, includes, wattle, include,
# Nearest to during: despite, until, in, since, shevat, throughout, after, within,
# Nearest to two: three, four, five, six, one, seven, cet, fm,
# Nearest to as: walruses, adom, mears, harbor, rub, warwickshire, spatially, kia,
# Nearest to it: he, she, probably, sewers, inaugurated, ornithologists, excavation, this,
# Nearest to most: especially, particularly, mayan, neuropsychological, ziibi, gripping, camped, basingstoke,
# Nearest to six: seven, four, eight, five, three, nine, pp, two,
# Nearest to seven: six, eight, four, nine, five, three, pp, two,
# Nearest to or: and, pancake, gravis, nabokov, sabres, immunoglobulins, lament, coms,
# Average loss at step 100000: 3.418738

# %%
# CBOW
def generate_cbow_batch(data, batch_size, window_size):
    """
    Generate CBOW batch, where batch consists of context words
    and label is the word itself
    """
    words_in_batch_number = (batch_size / window_size)
    batches_number = (len(data) - window_size) // words_in_batch_number
    for i in range(batches_number):
        batch = []
        labels = []
        for word_index in range(
                words_in_batch_number * i + window_size / 2, 
                words_in_batch_number * i + words_in_batch_number + window_size / 2):
            for context_index in range(
                    word_index - window_size / 2,
                    word_index + window_size / 2 + 1):
                if context_index == word_index:
                    continue
                batch.append(
                    data[context_index])
                labels.append(
                    data[word_index])
        yield np.array(batch), np.array(labels).reshape(-1, 1)


WINDOW_SIZE_CBOW = 2

BATCH_SIZE_CBOW = 128
VOCABULARY_SIZE_CBOW = 50000
EMBEDDING_SIZE_CBOW = 28 # Dimension of the embedding vector.
NUM_NEG_SOFTMAX_EXAMPLES_SAMPLED_CBOW = 64
NUM_STEPS_CBOW = 100001
NUM_POINTS_TO_SHOW_CBOW = 400

VALID_SIZE_CBOW = 16
VALID_WINDOW_CBOW = 100


run_word2vec_model(
    BATCH_SIZE_CBOW,
    VOCABULARY_SIZE_CBOW,
    EMBEDDING_SIZE_CBOW,
    NUM_NEG_SOFTMAX_EXAMPLES_SAMPLED_CBOW,
    NUM_STEPS_CBOW,
    NUM_POINTS_TO_SHOW_CBOW,

    VALID_SIZE_CBOW,
    VALID_WINDOW_CBOW,
    reverse_dictionary,
    
    data,
    partial(
        generate_cbow_batch,
        window_size=WINDOW_SIZE_CBOW)
)
# Out:
# Nearest to of: misspelled, nueva, esse, telescope, mercantilists, uploaded, gorman, edif,
# Nearest to however: puppetry, aromatherapy, cappadocia, oem, charms, replica, ostrogoths, focussed,
# Nearest to one: median, customs, pretensions, stds, lahoud, untimely, comers, seven,
# Nearest to seven: boitano, invitational, mcgwire, link, one, osteoarthritis, collectivism, transoxiana,
# Nearest to between: general, flanders, race, swabia, rudolph, cervantes, infra, dives,
# Nearest to this: education, premiums, weekday, hao, citadel, formalize, minibuses, determinism,
# Nearest to had: scorn, zvi, starling, aleksandar, ruining, gatherings, asu, qur,
# Nearest to are: plaster, tremolo, mt, declaration, illustration, katsura, groton, dominate,
# Nearest to system: fundamentalist, silvio, angular, olives, smyrnaeans, sher, astronomy, apparel,
# Nearest to an: morpheme, pashtun, benedict, vestments, primeval, prone, shot, attitudes,
# Nearest to would: sacrificial, corinne, sunset, humid, ssi, susceptibility, rask, comedic,
# Nearest to such: neurotransmitter, falsification, surfaces, nests, disagreeable, tina, hitpa, perish,
# Nearest to nine: describing, marcos, arbiter, nuts, toothpaste, oliva, server, kissing,
# Nearest to state: semiology, argento, bicycles, mchale, champlain, gygax, cool, helmets,
# Nearest to also: dunes, communicates, radiating, dominoes, vested, bow, settles, teng,
# Nearest to not: midwifery, straining, furor, stockpile, numbered, acronyms, imparted, catholicism,
# Average loss at step 2000: 4.443046
# Average loss at step 4000: 3.900080
# Average loss at step 6000: 3.831006
# Average loss at step 8000: 3.743439
# Nearest to of: investors, cmf, mercantilists, enterprise, during, telescope, folded, nueva,
# Nearest to however: but, while, for, when, schwa, slip, through, where,
# Nearest to one: two, seven, three, four, six, handler, billion, five,
# Nearest to seven: six, three, four, eight, five, nine, two, one,
# Nearest to between: during, from, with, including, mumbai, upon, trs, belly,
# Nearest to this: catchers, longfellow, rearmament, working, kau, it, discontented, which,
# Nearest to had: has, have, lachlan, took, brie, pied, westerly, hofmann,
# Nearest to are: were, is, curricula, overman, does, napo, thrives, though,
# Nearest to system: apparel, ligamentum, republican, department, college, aruban, astronomy, deng,
# Nearest to an: expropriation, aqueous, comiskey, chicanos, cooling, thrush, capitals, bradman,
# Nearest to would: can, may, will, could, creature, shattering, might, surrey,
# Nearest to such: well, psychomotor, redfern, fuerza, subjugation, finkel, sociopathic, alluded,
# Nearest to nine: eight, six, seven, three, five, four, zero, two,
# Nearest to state: semiology, cassatt, grams, argento, team, terminator, name, development,
# Nearest to also: often, now, still, codd, tore, harker, dungeons, cornell,
# Nearest to not: remission, we, syllabic, buzzard, it, busch, legation, generally,
# Average loss at step 10000: 3.635393
# Average loss at step 12000: 3.653732
# Average loss at step 14000: 3.638856
# Average loss at step 16000: 3.472549
# Average loss at step 18000: 3.432005
# Nearest to of: investors, mercantilists, tankers, including, during, ruiz, cmf, homestead,
# Nearest to however: but, since, when, if, that, where, while, though,
# Nearest to one: billion, two, three, four, six, maronite, catherine, eight,
# Nearest to seven: six, eight, four, five, three, nine, zero, two,
# Nearest to between: from, trs, upon, virus, incursion, famer, understandably, mumbai,
# Nearest to this: it, which, kau, no, catchers, longfellow, the, landing,
# Nearest to had: has, took, match, was, have, lachlan, store, honduras,
# Nearest to are: were, curricula, is, although, though, negative, cooperative, attended,
# Nearest to system: department, taekwondo, sanctuary, apparel, ligamentum, eugenicists, republican, monk,
# Nearest to an: chicanos, montmartre, thrush, mammals, premiership, themselves, expropriation, sends,
# Nearest to would: will, may, can, could, must, should, might, cannot,
# Nearest to such: well, flipping, finkel, arena, aral, conformal, redfern, exists,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to state: eastern, ate, abaye, eighth, conferring, government, multithreading, dozen,
# Nearest to also: often, now, generally, still, hurdler, sometimes, therefore, widely,
# Nearest to not: generally, buzzard, ousted, nestorianism, busch, syllabic, theorized, usually,
# Average loss at step 20000: 3.596304
# Average loss at step 22000: 3.535424
# Average loss at step 24000: 3.522009
# Average loss at step 26000: 3.529242
# Average loss at step 28000: 3.543419
# Nearest to of: mercantilists, ruiz, edif, flammable, rebuked, original, investors, middlesbrough,
# Nearest to however: but, when, though, while, if, although, really, where,
# Nearest to one: maronite, four, biography, eight, three, andronicus, mhz, two,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to between: trs, panel, incursion, with, from, virus, upon, understandably,
# Nearest to this: it, landing, catchers, which, kau, rearmament, barat, acquire,
# Nearest to had: has, took, have, store, honduras, takes, overman, match,
# Nearest to are: were, curricula, is, attended, while, hyperbolic, include, although,
# Nearest to system: apparel, ligamentum, monk, schottenheimer, sanctuary, glide, amun, kurukshetra,
# Nearest to an: premiership, amperes, montmartre, mammals, asahi, chicanos, melanchthon, grading,
# Nearest to would: may, could, will, can, must, should, might, cannot,
# Nearest to such: well, banisteriopsis, conformal, aral, extract, arena, flipping, exists,
# Nearest to nine: eight, seven, six, five, four, three, pmid, births,
# Nearest to state: irreversibly, government, southern, itasca, ate, barnet, numerology, council,
# Nearest to also: now, generally, typically, therefore, sometimes, still, actually, often,
# Nearest to not: generally, ousted, bono, busch, tuscan, fluctuated, quite, remission,
# Average loss at step 30000: 3.489814
# Average loss at step 32000: 3.557136
# Average loss at step 34000: 3.521813
# Average loss at step 36000: 3.539216
# Average loss at step 38000: 3.467521
# Nearest to of: cmf, ivies, bailiwicks, nicholls, fenrir, investors, grady, agrarian,
# Nearest to however: but, while, when, that, where, nevertheless, although, overlay,
# Nearest to one: two, eight, six, four, three, billion, seven, five,
# Nearest to seven: six, four, five, eight, three, nine, zero, two,
# Nearest to between: panel, trs, ec, artois, chisholm, setback, understandably, incursion,
# Nearest to this: it, kau, barat, honorary, rearmament, landing, lang, cet,
# Nearest to had: has, have, store, got, took, lachlan, previously, overman,
# Nearest to are: were, attended, inferences, thermometers, astrometry, dairy, pu, yeo,
# Nearest to system: glide, resolution, sanctuary, abaye, systems, department, pensacola, erg,
# Nearest to an: amperes, premiership, montmartre, chicanos, magnum, catastrophes, businessmen, melanchthon,
# Nearest to would: will, could, can, must, may, should, might, cannot,
# Nearest to such: well, conformal, aral, kindergarten, poole, flipping, duffy, ambitions,
# Nearest to nine: eight, six, seven, five, four, three, zero, ranked,
# Nearest to state: government, aberdeen, abaye, territory, definition, lighted, leadership, council,
# Nearest to also: sometimes, actually, champs, typically, still, now, diarrhoea, generally,
# Nearest to not: ousted, generally, still, usually, francois, tuscan, quite, beverley,
# Average loss at step 40000: 3.393195
# Average loss at step 42000: 3.472849
# Average loss at step 44000: 3.479337
# Average loss at step 46000: 3.497469
# Average loss at step 48000: 3.490953
# Nearest to of: ivies, fenrir, cmf, playfulness, bailiwicks, vestigial, fiske, nicholls,
# Nearest to however: but, although, where, when, though, while, that, furthermore,
# Nearest to one: two, three, four, six, eight, seven, five, lb,
# Nearest to seven: six, eight, five, four, three, nine, two, zero,
# Nearest to between: trs, panel, artois, incursion, from, ec, setback, fandom,
# Nearest to this: it, kau, which, rearmament, lang, barat, tabloids, what,
# Nearest to had: has, have, got, store, kinks, began, honduras, southey,
# Nearest to are: were, attended, hyperbolic, astrometry, pu, thermometers, juris, aymara,
# Nearest to system: glide, landslides, irrespective, commuted, systems, sanctuary, unscr, rumi,
# Nearest to an: premiership, amperes, einsteinium, inquiring, mammals, melanchthon, magnum, varies,
# Nearest to would: could, will, must, can, should, may, might, cannot,
# Nearest to such: well, arena, rewarded, flipping, poole, banisteriopsis, aral, notable,
# Nearest to nine: eight, six, seven, five, three, four, two, zero,
# Nearest to state: herds, abaye, aberdeen, council, numerology, barnet, leadership, republicanism,
# Nearest to also: now, sometimes, actually, still, typically, diarrhoea, officially, currently,
# Nearest to not: glued, tuscan, remission, actually, francois, resembled, ousted, anything,
# Average loss at step 50000: 3.412368
# Average loss at step 52000: 3.407639
# Average loss at step 54000: 3.463103
# Average loss at step 56000: 3.470280
# Average loss at step 58000: 3.494508
# Nearest to of: flammable, rebuked, esr, tankers, octavia, agrarian, edif, current,
# Nearest to however: nevertheless, although, but, though, today, beset, unless, while,
# Nearest to one: two, six, four, three, seven, five, eight, lb,
# Nearest to seven: six, eight, four, five, nine, three, zero, billion,
# Nearest to between: panel, trs, hitchhikers, artois, understandably, hanoverian, hexagrams, drunken,
# Nearest to this: it, which, kau, occurring, chechen, holiday, landing, aisles,
# Nearest to had: has, have, got, took, overman, began, having, produces,
# Nearest to are: were, thrives, include, hyperbolic, dairy, login, thermometers, cooperative,
# Nearest to system: systems, glide, resolution, abaye, leaguers, structure, irrespective, phonology,
# Nearest to an: amperes, premiership, bolstered, melanchthon, einsteinium, magnum, guillermo, monuments,
# Nearest to would: could, must, should, might, will, may, can, cannot,
# Nearest to such: well, innovators, bayesian, rewarded, poole, arena, flipping, conformal,
# Nearest to nine: eight, six, seven, four, five, three, pp, billion,
# Nearest to state: council, aberdeen, abaye, republicanism, alliance, definition, republican, kirkpatrick,
# Nearest to also: now, currently, sometimes, actually, therefore, champs, still, morrie,
# Nearest to not: ousted, rarely, still, usually, tuscan, actually, glued, francois,
# Average loss at step 60000: 3.422544
# Average loss at step 62000: 3.480328
# Average loss at step 64000: 3.411486
# Average loss at step 66000: 3.169109
# Average loss at step 68000: 3.495503
# Nearest to of: ivies, cmf, playfulness, fenrir, variational, diels, grady, nicholls,
# Nearest to however: but, although, nonetheless, nevertheless, though, while, despite, when,
# Nearest to one: lb, six, four, boo, two, three, jabberwock, five,
# Nearest to seven: eight, six, nine, five, four, three, pp, billion,
# Nearest to between: with, hitchhikers, artois, panel, trs, from, allowing, against,
# Nearest to this: it, which, kau, itself, what, walkers, baptism, flattening,
# Nearest to had: has, got, have, kinks, having, took, produces, sought,
# Nearest to are: were, hyperbolic, apc, login, capablanca, juris, lumbar, thermometers,
# Nearest to system: systems, glide, landslides, irrespective, program, phenomenon, dialect, montmartre,
# Nearest to an: amperes, einsteinium, webcomics, gyms, bolstered, premiership, syntax, hydrothermal,
# Nearest to would: could, will, might, must, should, may, can, cannot,
# Nearest to such: well, poole, innovators, rewarded, flipping, bayesian, solfege, arena,
# Nearest to nine: eight, seven, six, five, four, three, billion, ff,
# Nearest to state: leadership, aberdeen, nation, council, numerology, definition, pairwise, government,
# Nearest to also: now, sometimes, currently, actually, therefore, often, still, generally,
# Nearest to not: rarely, ousted, possibly, actually, glued, tuscan, therefore, francois,
# Average loss at step 70000: 3.442781
# Average loss at step 72000: 3.411372
# Average loss at step 74000: 3.434911
# Average loss at step 76000: 3.403353
# Average loss at step 78000: 3.437062
